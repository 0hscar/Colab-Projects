# %%
from scipy.stats import norm
mu_X_new = 0.15
sigma_X_new = 0.02
mu_Y_new = 0.40
sigma_Y_new = 0.05

# For Signal S with new coefficients:
# Calculate mean (mu_S_new) and standard deviation (sigma_S_new) of S
mu_S_new = 4 * mu_X_new + 2 * mu_Y_new
sigma_S_new = (16 * sigma_X_new**2 + 4 * sigma_Y_new**2)**0.5

# Calculate the probability that S < 1.33
P_S_new = norm.cdf(1.33, mu_S_new, sigma_S_new)

# For Total Weight T with new coefficients:
# Calculate mean (mu_T_new) and standard deviation (sigma_T_new) of T
mu_T_new = 4 * mu_X_new + 2 * mu_Y_new
sigma_T_new = (4 * sigma_X_new**2 + 2 * sigma_Y_new**2)**0.5

# Calculate the probability that T < 1.33
P_T_new = norm.cdf(1.33, mu_T_new, sigma_T_new)

mu_S_new, sigma_S_new, P_S_new, mu_T_new, sigma_T_new, P_T_new
# Out:
# (1.4,
#  0.12806248474865697,
#  0.29232397863569065,
#  1.4,
#  0.08124038404635961,
#  0.19444270590388307)

# %% [markdown]
# a) 0.13
# b) 0.29
# c) 0.081
# d) 0.19

# %%
mu_X_new = 0.20
sigma_X_new = 0.05
mu_Y_new = 0.35
sigma_Y_new = 0.05

# Signal S with new coefficients:
# mean (mu_S_new) and standard deviation (sigma_S_new) of S
mu_S_new = 3 * mu_X_new + 2 * mu_Y_new
sigma_S_new = (9 * sigma_X_new**2 + 4 * sigma_Y_new**2)**0.5

# probability that S < 1.33
P_S_new = norm.cdf(1.23, mu_S_new, sigma_S_new)

# For Total Weight T with new coefficients:
# Calculate mean (mu_T_new) and standard deviation (sigma_T_new) of T
mu_T_new = 3 * mu_X_new + 2 * mu_Y_new
sigma_T_new = (3 * sigma_X_new**2 + 2 * sigma_Y_new**2)**0.5

# Calculate the probability that T < 1.33
P_T_new = norm.cdf(1.23, mu_T_new, sigma_T_new)

mu_S_new, sigma_S_new, P_S_new, mu_T_new, sigma_T_new, P_T_new
# Out:
# (1.3,
#  0.18027756377319948,
#  0.34890066754225424,
#  1.3,
#  0.1118033988749895,
#  0.2656249929974239)

# %% [markdown]
# a) 0.18
# b) 0.35
# c) 0.11
# d) 0.27
